# %%
# https://stackoverflow.com/questions/64261546/how-to-solve-error-microsoft-visual-c-14-0-or-greater-is-required-when-inst
# !pip install hnswlib
# Out:
# Collecting hnswlib
#   Using cached hnswlib-0.6.2.tar.gz (31 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\soiko\anaconda3\lib\site-packages (from hnswlib) (1.22.4)
# Building wheels for collected packages: hnswlib
#   Building wheel for hnswlib (pyproject.toml): started
#   Building wheel for hnswlib (pyproject.toml): finished with status 'done'
#   Created wheel for hnswlib: filename=hnswlib-0.6.2-cp39-cp39-win_amd64.whl size=135742 sha256=2eca5754dd5269c60b5fcd0470c0be1dd3056ffb2a817d47c984469358c1e51b
#   Stored in directory: c:\users\soiko\appdata\local\pip\cache\wheels\42\ef\fe\bab7e480effd9f1bb90c3dfc354ac1bceb27eb0f7e0877efdc
# Successfully built hnswlib
# Installing collected packages: hnswlib
# Successfully installed hnswlib-0.6.2

# %%
# https://github.com/facebookresearch/faiss/blob/main/INSTALL.md
# conda install -c conda-forge faiss-cpu
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.14.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\soiko\anaconda3
#
#   added / updated specs:
#     - faiss-cpu
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.9.24  |       h5b45459_0         189 KB  conda-forge
#     certifi-2022.9.24          |     pyhd8ed1ab_0         155 KB  conda-forge
#     conda-22.9.0               |   py39hcbf5309_1         968 KB  conda-forge
#     faiss-1.7.2                |py39hfccd52d_1_cpu         1.6 MB  conda-forge
#     faiss-cpu-1.7.2            |       hf9c7e24_1          15 KB  conda-forge
#     libblas-3.9.0              |1_h8933c1f_netlib         193 KB  conda-forge
#     libfaiss-1.7.2             |   hba6d9cf_1_cpu         974 KB  conda-forge
#     libfaiss-avx2-1.7.2        |   h1234567_1_cpu         985 KB  conda-forge
#     liblapack-3.9.0            |5_hd5c7e75_netlib         2.7 MB  conda-forge
#     m2w64-gcc-libgfortran-5.3.0|                6         342 KB  conda-forge
#     m2w64-gcc-libs-5.3.0       |                7         520 KB  conda-forge
#     m2w64-gcc-libs-core-5.3.0  |                7         214 KB  conda-forge
#     m2w64-gmp-6.1.0            |                2         726 KB  conda-forge
#     openssl-1.1.1q             |       hcfcfb64_1         6.0 MB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     ucrt-10.0.22621.0          |       h57928b3_0         1.2 MB  conda-forge
#     vs2015_runtime-14.32.31332 |       h1d6e394_9         1.2 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        18.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   faiss              conda-forge/win-64::faiss-1.7.2-py39hfccd52d_1_cpu
#   faiss-cpu          conda-forge/win-64::faiss-cpu-1.7.2-hf9c7e24_1
#   libblas            conda-forge/win-64::libblas-3.9.0-1_h8933c1f_netlib
#   libfaiss           conda-forge/win-64::libfaiss-1.7.2-hba6d9cf_1_cpu
#   libfaiss-avx2      conda-forge/win-64::libfaiss-avx2-1.7.2-h1234567_1_cpu
#   liblapack          conda-forge/win-64::liblapack-3.9.0-5_hd5c7e75_netlib
#   m2w64-gcc-libgfor~ conda-forge/win-64::m2w64-gcc-libgfortran-5.3.0-6
#   m2w64-gcc-libs     conda-forge/win-64::m2w64-gcc-libs-5.3.0-7
#   m2w64-gcc-libs-co~ conda-forge/win-64::m2w64-gcc-libs-core-5.3.0-7
#   m2w64-gmp          conda-forge/win-64::m2w64-gmp-6.1.0-2
#   python_abi         conda-forge/win-64::python_abi-3.9-2_cp39
#   ucrt               conda-forge/win-64::ucrt-10.0.22621.0-h57928b3_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.07.19~ --> conda-forge::ca-certificates-2022.9.24-h5b45459_0
#   certifi            pkgs/main/win-64::certifi-2022.6.15-p~ --> conda-forge/noarch::certifi-2022.9.24-pyhd8ed1ab_0
#   conda              pkgs/main::conda-4.14.0-py39haa95532_0 --> conda-forge::conda-22.9.0-py39hcbf5309_1
#   openssl              pkgs/main::openssl-1.1.1q-h2bbff1b_0 --> conda-forge::openssl-1.1.1q-hcfcfb64_1
#   vs2015_runtime     pkgs/main::vs2015_runtime-14.27.29016~ --> conda-forge::vs2015_runtime-14.32.31332-h1d6e394_9
#
#
#
# Downloading and Extracting Packages
#
# vs2015_runtime-14.32 | 1.2 MB    |            |   0%
# vs2015_runtime-14.32 | 1.2 MB    | 1          |   1%
# vs2015_runtime-14.32 | 1.2 MB    | #####5     |  55%
# vs2015_runtime-14.32 | 1.2 MB    | ########## | 100%
# vs2015_runtime-14.32 | 1.2 MB    | ########## | 100%
#
# openssl-1.1.1q       | 6.0 MB    |            |   0%
# openssl-1.1.1q       | 6.0 MB    | #1         |  11%
# openssl-1.1.1q       | 6.0 MB    | ##5        |  25%
# openssl-1.1.1q       | 6.0 MB    | ####       |  41%
# openssl-1.1.1q       | 6.0 MB    | #####4     |  55%
# openssl-1.1.1q       | 6.0 MB    | ######6    |  67%
# openssl-1.1.1q       | 6.0 MB    | #######7   |  77%
# openssl-1.1.1q       | 6.0 MB    | ########6  |  87%
# openssl-1.1.1q       | 6.0 MB    | #########5 |  96%
# openssl-1.1.1q       | 6.0 MB    | ########## | 100%
#
# libblas-3.9.0        | 193 KB    |            |   0%
# libblas-3.9.0        | 193 KB    | ########## | 100%
# libblas-3.9.0        | 193 KB    | ########## | 100%
#
# faiss-cpu-1.7.2      | 15 KB     |            |   0%
# faiss-cpu-1.7.2      | 15 KB     | ########## | 100%
# faiss-cpu-1.7.2      | 15 KB     | ########## | 100%
#
# ca-certificates-2022 | 189 KB    |            |   0%
# ca-certificates-2022 | 189 KB    | ########## | 100%
# ca-certificates-2022 | 189 KB    | ########## | 100%
#
# libfaiss-avx2-1.7.2  | 985 KB    |            |   0%
# libfaiss-avx2-1.7.2  | 985 KB    | 1          |   2%
# libfaiss-avx2-1.7.2  | 985 KB    | ######     |  60%
# libfaiss-avx2-1.7.2  | 985 KB    | ########## | 100%
# libfaiss-avx2-1.7.2  | 985 KB    | ########## | 100%
#
# conda-22.9.0         | 968 KB    |            |   0%
# conda-22.9.0         | 968 KB    | ####9      |  50%
# conda-22.9.0         | 968 KB    | ########## | 100%
# conda-22.9.0         | 968 KB    | ########## | 100%
#
# faiss-1.7.2          | 1.6 MB    |            |   0%
# faiss-1.7.2          | 1.6 MB    |            |   1%
# faiss-1.7.2          | 1.6 MB    | 2          |   3%
# faiss-1.7.2          | 1.6 MB    | 6          |   7%
# faiss-1.7.2          | 1.6 MB    | 8          |   9%
# faiss-1.7.2          | 1.6 MB    | 9          |  10%
# faiss-1.7.2          | 1.6 MB    | #2         |  12%
# faiss-1.7.2          | 1.6 MB    | #5         |  15%
# faiss-1.7.2          | 1.6 MB    | #8         |  18%
# faiss-1.7.2          | 1.6 MB    | ##         |  20%
# faiss-1.7.2          | 1.6 MB    | ##1        |  22%
# faiss-1.7.2          | 1.6 MB    | ##5        |  26%
# faiss-1.7.2          | 1.6 MB    | ##7        |  28%
# faiss-1.7.2          | 1.6 MB    | ##9        |  30%
# faiss-1.7.2          | 1.6 MB    | ###3       |  33%
# faiss-1.7.2          | 1.6 MB    | ###7       |  37%
# faiss-1.7.2          | 1.6 MB    | ####1      |  41%
# faiss-1.7.2          | 1.6 MB    | ####4      |  45%
# faiss-1.7.2          | 1.6 MB    | ####8      |  49%
# faiss-1.7.2          | 1.6 MB    | #####1     |  52%
# faiss-1.7.2          | 1.6 MB    | #####5     |  55%
# faiss-1.7.2          | 1.6 MB    | #####8     |  58%
# faiss-1.7.2          | 1.6 MB    | ######2    |  62%
# faiss-1.7.2          | 1.6 MB    | ######6    |  67%
# faiss-1.7.2          | 1.6 MB    | #######    |  71%
# faiss-1.7.2          | 1.6 MB    | #######6   |  76%
# faiss-1.7.2          | 1.6 MB    | ########3  |  83%
# faiss-1.7.2          | 1.6 MB    | #########  |  91%
# faiss-1.7.2          | 1.6 MB    | #########5 |  95%
# faiss-1.7.2          | 1.6 MB    | ########## | 100%
# faiss-1.7.2          | 1.6 MB    | ########## | 100%
#
# m2w64-gcc-libgfortra | 342 KB    |            |   0%
# m2w64-gcc-libgfortra | 342 KB    | 4          |   5%
# m2w64-gcc-libgfortra | 342 KB    | #4         |  14%
# m2w64-gcc-libgfortra | 342 KB    | ###7       |  37%
# m2w64-gcc-libgfortra | 342 KB    | #####6     |  56%
# m2w64-gcc-libgfortra | 342 KB    | ########## | 100%
# m2w64-gcc-libgfortra | 342 KB    | ########## | 100%
# m2w64-gcc-libs-core- | 214 KB    |            |   0%
# m2w64-gcc-libs-core- | 214 KB    | 7          |   7%
# m2w64-gcc-libs-core- | 214 KB    | ##2        |  22%
# m2w64-gcc-libs-core- | 214 KB    | #####9     |  60%
# m2w64-gcc-libs-core- | 214 KB    | ########## | 100%
# m2w64-gcc-libs-core- | 214 KB    | ########## | 100%
#
# m2w64-gmp-6.1.0      | 726 KB    |            |   0%
# m2w64-gmp-6.1.0      | 726 KB    | 2          |   2%
# m2w64-gmp-6.1.0      | 726 KB    | 6          |   7%
# m2w64-gmp-6.1.0      | 726 KB    | #9         |  20%
# m2w64-gmp-6.1.0      | 726 KB    | ##8        |  29%
# m2w64-gmp-6.1.0      | 726 KB    | ###9       |  40%
# m2w64-gmp-6.1.0      | 726 KB    | ####8      |  48%
# m2w64-gmp-6.1.0      | 726 KB    | #####7     |  57%
# m2w64-gmp-6.1.0      | 726 KB    | ######6    |  66%
# m2w64-gmp-6.1.0      | 726 KB    | ########1  |  82%
# m2w64-gmp-6.1.0      | 726 KB    | #########2 |  93%
# m2w64-gmp-6.1.0      | 726 KB    | ########## | 100%
#
# m2w64-gcc-libs-5.3.0 | 520 KB    |            |   0%
# m2w64-gcc-libs-5.3.0 | 520 KB    | 3          |   3%
# m2w64-gcc-libs-5.3.0 | 520 KB    | 9          |   9%
# m2w64-gcc-libs-5.3.0 | 520 KB    | ##7        |  28%
# m2w64-gcc-libs-5.3.0 | 520 KB    | ####       |  40%
# m2w64-gcc-libs-5.3.0 | 520 KB    | #####2     |  52%
# m2w64-gcc-libs-5.3.0 | 520 KB    | ######7    |  68%
# m2w64-gcc-libs-5.3.0 | 520 KB    | #######6   |  77%
# m2w64-gcc-libs-5.3.0 | 520 KB    | ########## | 100%
# m2w64-gcc-libs-5.3.0 | 520 KB    | ########## | 100%
#
# libfaiss-1.7.2       | 974 KB    |            |   0%
# libfaiss-1.7.2       | 974 KB    | 1          |   2%
# libfaiss-1.7.2       | 974 KB    | 4          |   5%
# libfaiss-1.7.2       | 974 KB    | #3         |  13%
# libfaiss-1.7.2       | 974 KB    | #8         |  18%
# libfaiss-1.7.2       | 974 KB    | ##7        |  28%
# libfaiss-1.7.2       | 974 KB    | ###4       |  34%
# libfaiss-1.7.2       | 974 KB    | ####2      |  43%
# libfaiss-1.7.2       | 974 KB    | ####9      |  49%
# libfaiss-1.7.2       | 974 KB    | #####7     |  57%
# libfaiss-1.7.2       | 974 KB    | ######8    |  69%
# libfaiss-1.7.2       | 974 KB    | #######7   |  77%
# libfaiss-1.7.2       | 974 KB    | ########8  |  89%
# libfaiss-1.7.2       | 974 KB    | ########## | 100%
# libfaiss-1.7.2       | 974 KB    | ########## | 100%
#
# liblapack-3.9.0      | 2.7 MB    |            |   0%
# liblapack-3.9.0      | 2.7 MB    | ##1        |  22%
# liblapack-3.9.0      | 2.7 MB    | ######     |  61%
# liblapack-3.9.0      | 2.7 MB    | #########2 |  93%
# liblapack-3.9.0      | 2.7 MB    | ########## | 100%
#
# certifi-2022.9.24    | 155 KB    |            |   0%
# certifi-2022.9.24    | 155 KB    | ########## | 100%
# certifi-2022.9.24    | 155 KB    | ########## | 100%
#
# python_abi-3.9       | 4 KB      |            |   0%
# python_abi-3.9       | 4 KB      | ########## | 100%
#
# ucrt-10.0.22621.0    | 1.2 MB    |            |   0%
# ucrt-10.0.22621.0    | 1.2 MB    | #####4     |  55%
# ucrt-10.0.22621.0    | 1.2 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done

# %%
conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\soiko\anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anaconda-client-1.11.0     |   py39haa95532_0         165 KB
#     async-timeout-4.0.2        |   py39haa95532_0          12 KB
#     blosc-1.21.0               |       h19a0ad4_1         145 KB
#     certifi-2022.9.24          |   py39haa95532_0         154 KB
#     conda-22.9.0               |   py39haa95532_0         888 KB
#     conda-package-handling-1.9.0|   py39h8cc25b3_0         726 KB
#     conda-repo-cli-1.0.20      |   py39haa95532_0         126 KB
#     conda-token-0.4.0          |     pyhd3eb1b0_0          13 KB
#     cryptography-38.0.1        |   py39h21b164f_0         991 KB
#     cython-0.29.32             |   py39hd77b12b_0         1.7 MB
#     daal4py-2021.6.0           |   py39h757b272_1         8.0 MB
#     dal-2021.6.0               |     h59b6b97_874        46.5 MB
#     google-api-core-2.10.1     |   py39haa95532_0         119 KB
#     icc_rt-2022.1.0            |       h6049295_2         6.5 MB
#     idna-3.4                   |   py39haa95532_0          93 KB
#     imagecodecs-2021.8.26      |   py39hc0a7faf_1         6.0 MB
#     ipykernel-6.15.2           |   py39haa95532_0         191 KB
#     joblib-1.1.1               |   py39haa95532_0         383 KB
#     jsonschema-4.16.0          |   py39haa95532_0         143 KB
#     jupyter_core-4.11.1        |   py39haa95532_0          93 KB
#     libarchive-3.6.1           |       hebabd0d_0         1.7 MB
#     libwebp-1.2.4              |       h2bbff1b_0          67 KB
#     libwebp-base-1.2.4         |       h2bbff1b_0         279 KB
#     matplotlib-inline-0.1.6    |   py39haa95532_0          17 KB
#     multidict-6.0.2            |   py39h2bbff1b_0          46 KB
#     nbformat-5.5.0             |   py39haa95532_0         146 KB
#     pandas-1.4.4               |   py39hd77b12b_0         8.7 MB
#     pip-22.2.2                 |   py39haa95532_0         2.3 MB
#     platformdirs-2.5.2         |   py39haa95532_0          24 KB
#     qtconsole-5.3.2            |   py39haa95532_0         202 KB
#     qtpy-2.2.0                 |   py39haa95532_0         106 KB
#     scikit-learn-intelex-2021.6.0|   py39haa95532_0          75 KB
#     scipy-1.9.1                |   py39he11b74f_0        15.7 MB
#     seaborn-0.12.0             |   py39haa95532_0         435 KB
#     soupsieve-2.3.2.post1      |   py39haa95532_0          66 KB
#     sqlite-3.39.3              |       h2bbff1b_0         804 KB
#     tbb-2021.6.0               |       h59b6b97_0         135 KB
#     tbb4py-2021.6.0            |   py39h59b6b97_0          63 KB
#     tqdm-4.64.1                |   py39haa95532_0         143 KB
#     tzdata-2022e               |       h04d1e81_0         107 KB
#     ucrt-10.0.20348.0          |       haa95532_0         531 KB
#     urllib3-1.26.12            |   py39haa95532_0         185 KB
#     xlwings-0.27.15            |   py39haa95532_0         1.1 MB
#     xz-5.2.6                   |       h8cc25b3_0         240 KB
#     zlib-1.2.13                |       h8cc25b3_0         113 KB
#     zstd-1.5.2                 |       h19a0ad4_0         509 KB
#     ------------------------------------------------------------
#                                            Total:       106.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   libwebp-base       pkgs/main/win-64::libwebp-base-1.2.4-h2bbff1b_0 None
#
# The following packages will be UPDATED:
#
#   anaconda-client                     1.10.0-py39haa95532_0 --> 1.11.0-py39haa95532_0 None
#   async-timeout      pkgs/main/noarch::async-timeout-4.0.1~ --> pkgs/main/win-64::async-timeout-4.0.2-py39haa95532_0 None
#   blosc                                   1.21.0-h19a0ad4_0 --> 1.21.0-h19a0ad4_1 None
#   conda-package-han~                   1.8.1-py39h8cc25b3_0 --> 1.9.0-py39h8cc25b3_0 None
#   conda-repo-cli                       1.0.5-py39haa95532_0 --> 1.0.20-py39haa95532_0 None
#   conda-token                            0.3.0-pyhd3eb1b0_0 --> 0.4.0-pyhd3eb1b0_0 None
#   cryptography                        37.0.1-py39h21b164f_0 --> 38.0.1-py39h21b164f_0 None
#   cython                             0.29.30-py39hd77b12b_0 --> 0.29.32-py39hd77b12b_0 None
#   daal4py                           2021.5.0-py39h8cb3d55_0 --> 2021.6.0-py39h757b272_1 None
#   dal                                 2021.5.0-haa95532_796 --> 2021.6.0-h59b6b97_874 None
#   google-api-core    pkgs/main/noarch::google-api-core-2.2~ --> pkgs/main/win-64::google-api-core-2.10.1-py39haa95532_0 None
#   icc_rt                                2019.0.0-h0cc432a_1 --> 2022.1.0-h6049295_2 None
#   idna               pkgs/main/noarch::idna-3.3-pyhd3eb1b0~ --> pkgs/main/win-64::idna-3.4-py39haa95532_0 None
#   imagecodecs                      2021.8.26-py39ha1f97ea_0 --> 2021.8.26-py39hc0a7faf_1 None
#   ipykernel                            6.9.1-py39haa95532_0 --> 6.15.2-py39haa95532_0 None
#   joblib             pkgs/main/noarch::joblib-1.1.0-pyhd3e~ --> pkgs/main/win-64::joblib-1.1.1-py39haa95532_0 None
#   jsonschema                           4.4.0-py39haa95532_0 --> 4.16.0-py39haa95532_0 None
#   jupyter_core                        4.10.0-py39haa95532_0 --> 4.11.1-py39haa95532_0 None
#   libarchive                               3.4.2-h5e25573_0 --> 3.6.1-hebabd0d_0 None
#   libwebp                                  1.2.2-h2bbff1b_0 --> 1.2.4-h2bbff1b_0 None
#   matplotlib-inline  pkgs/main/noarch::matplotlib-inline-0~ --> pkgs/main/win-64::matplotlib-inline-0.1.6-py39haa95532_0 None
#   multidict                            5.1.0-py39h2bbff1b_2 --> 6.0.2-py39h2bbff1b_0 None
#   nbformat                             5.3.0-py39haa95532_0 --> 5.5.0-py39haa95532_0 None
#   pandas                               1.4.3-py39hd77b12b_0 --> 1.4.4-py39hd77b12b_0 None
#   pip                                 22.1.2-py39haa95532_0 --> 22.2.2-py39haa95532_0 None
#   platformdirs       pkgs/main/noarch::platformdirs-2.4.0-~ --> pkgs/main/win-64::platformdirs-2.5.2-py39haa95532_0 None
#   qtconsole                            5.3.1-py39haa95532_1 --> 5.3.2-py39haa95532_0 None
#   qtpy               pkgs/main/noarch::qtpy-2.0.1-pyhd3eb1~ --> pkgs/main/win-64::qtpy-2.2.0-py39haa95532_0 None
#   scikit-learn-inte~                2021.5.0-py39haa95532_0 --> 2021.6.0-py39haa95532_0 None
#   scipy                                1.7.3-py39h7a0a035_2 --> 1.9.1-py39he11b74f_0 None
#   seaborn            pkgs/main/noarch::seaborn-0.11.2-pyhd~ --> pkgs/main/win-64::seaborn-0.12.0-py39haa95532_0 None
#   soupsieve          pkgs/main/noarch::soupsieve-2.3.1-pyh~ --> pkgs/main/win-64::soupsieve-2.3.2.post1-py39haa95532_0 None
#   sqlite                                  3.39.2-h2bbff1b_0 --> 3.39.3-h2bbff1b_0 None
#   tbb                                   2021.5.0-h59b6b97_0 --> 2021.6.0-h59b6b97_0 None
#   tbb4py                            2021.5.0-py39h59b6b97_0 --> 2021.6.0-py39h59b6b97_0 None
#   tqdm                                4.64.0-py39haa95532_0 --> 4.64.1-py39haa95532_0 None
#   tzdata                                   2022a-hda174b7_0 --> 2022e-h04d1e81_0 None
#   urllib3                            1.26.11-py39haa95532_0 --> 1.26.12-py39haa95532_0 None
#   xlwings                             0.24.9-py39haa95532_0 --> 0.27.15-py39haa95532_0 None
#   xz                                       5.2.5-h8cc25b3_1 --> 5.2.6-h8cc25b3_0 None
#   zlib                                    1.2.12-h8cc25b3_2 --> 1.2.13-h8cc25b3_0 None
#   zstd                                     1.4.9-h19a0ad4_0 --> 1.5.2-h19a0ad4_0 None
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2022.9.2~ --> pkgs/main::ca-certificates-2022.07.19-haa95532_0 None
#   certifi            conda-forge/noarch::certifi-2022.9.24~ --> pkgs/main/win-64::certifi-2022.9.24-py39haa95532_0 None
#   conda              conda-forge::conda-22.9.0-py39hcbf530~ --> pkgs/main::conda-22.9.0-py39haa95532_0 None
#   openssl            conda-forge::openssl-1.1.1q-hcfcfb64_1 --> pkgs/main::openssl-1.1.1q-h2bbff1b_0 None
#   ucrt               conda-forge::ucrt-10.0.22621.0-h57928~ --> pkgs/main::ucrt-10.0.20348.0-haa95532_0 None
#
# The following packages will be DOWNGRADED:
#
# Note: you may need to restart the kernel to use updated packages.
#
#   scikit-learn                         1.1.1-py39hd77b12b_0 --> 1.0.2-py39hf11a4ad_1 None
#
#
#
# Downloading and Extracting Packages
#
# sqlite-3.39.3        | 804 KB    |            |   0%
# sqlite-3.39.3        | 804 KB    | #5         |  16%
# sqlite-3.39.3        | 804 KB    | ########## | 100%
# sqlite-3.39.3        | 804 KB    | ########## | 100%
#
# platformdirs-2.5.2   | 24 KB     |            |   0%
# platformdirs-2.5.2   | 24 KB     | ######7    |  67%
# platformdirs-2.5.2   | 24 KB     | ########## | 100%
# platformdirs-2.5.2   | 24 KB     | ########## | 100%
#
# tbb-2021.6.0         | 135 KB    |            |   0%
# tbb-2021.6.0         | 135 KB    | #1         |  12%
# tbb-2021.6.0         | 135 KB    | ###5       |  36%
# tbb-2021.6.0         | 135 KB    | ########## | 100%
# tbb-2021.6.0         | 135 KB    | ########## | 100%
#
# conda-package-handli | 726 KB    |            |   0%
# conda-package-handli | 726 KB    | ########## | 100%
# conda-package-handli | 726 KB    | ########## | 100%
#
# conda-token-0.4.0    | 13 KB     |            |   0%
# conda-token-0.4.0    | 13 KB     | ########## | 100%
# conda-token-0.4.0    | 13 KB     | ########## | 100%
#
# nbformat-5.5.0       | 146 KB    |            |   0%
# nbformat-5.5.0       | 146 KB    | ########## | 100%
# nbformat-5.5.0       | 146 KB    | ########## | 100%
#
# matplotlib-inline-0. | 17 KB     |            |   0%
# matplotlib-inline-0. | 17 KB     | ########## | 100%
# matplotlib-inline-0. | 17 KB     | ########## | 100%
#
# jupyter_core-4.11.1  | 93 KB     |            |   0%
# jupyter_core-4.11.1  | 93 KB     | ########## | 100%
# jupyter_core-4.11.1  | 93 KB     | ########## | 100%
#
# ucrt-10.0.20348.0    | 531 KB    |            |   0%
# ucrt-10.0.20348.0    | 531 KB    | 3          |   3%
# ucrt-10.0.20348.0    | 531 KB    | 9          |   9%
# ucrt-10.0.20348.0    | 531 KB    | ##1        |  21%
# ucrt-10.0.20348.0    | 531 KB    | ##7        |  27%
# ucrt-10.0.20348.0    | 531 KB    | ###3       |  33%
# ucrt-10.0.20348.0    | 531 KB    | ####5      |  45%
# ucrt-10.0.20348.0    | 531 KB    | #####4     |  54%
# ucrt-10.0.20348.0    | 531 KB    | ########1  |  81%
# ucrt-10.0.20348.0    | 531 KB    | #########3 |  93%
# ucrt-10.0.20348.0    | 531 KB    | ########## | 100%
#
# conda-22.9.0         | 888 KB    |            |   0%
# conda-22.9.0         | 888 KB    | ##8        |  29%
# conda-22.9.0         | 888 KB    | #######3   |  74%
# conda-22.9.0         | 888 KB    | ########## | 100%
#
# ipykernel-6.15.2     | 191 KB    |            |   0%
# ipykernel-6.15.2     | 191 KB    | ########## | 100%
# ipykernel-6.15.2     | 191 KB    | ########## | 100%
#
# xz-5.2.6             | 240 KB    |            |   0%
# xz-5.2.6             | 240 KB    | ########## | 100%
# xz-5.2.6             | 240 KB    | ########## | 100%
#
# certifi-2022.9.24    | 154 KB    |            |   0%
# certifi-2022.9.24    | 154 KB    | ########## | 100%
# certifi-2022.9.24    | 154 KB    | ########## | 100%
#
# imagecodecs-2021.8.2 | 6.0 MB    |            |   0%
# imagecodecs-2021.8.2 | 6.0 MB    |            |   0%
# imagecodecs-2021.8.2 | 6.0 MB    |            |   1%
# imagecodecs-2021.8.2 | 6.0 MB    | 1          |   1%
# imagecodecs-2021.8.2 | 6.0 MB    | 1          |   2%
# imagecodecs-2021.8.2 | 6.0 MB    | 2          |   2%
# imagecodecs-2021.8.2 | 6.0 MB    | 3          |   3%
# imagecodecs-2021.8.2 | 6.0 MB    | 3          |   4%
# imagecodecs-2021.8.2 | 6.0 MB    | 4          |   4%
# imagecodecs-2021.8.2 | 6.0 MB    | 4          |   5%
# imagecodecs-2021.8.2 | 6.0 MB    | 5          |   5%
# imagecodecs-2021.8.2 | 6.0 MB    | 5          |   6%
# imagecodecs-2021.8.2 | 6.0 MB    | 6          |   7%
# imagecodecs-2021.8.2 | 6.0 MB    | 7          |   7%
# imagecodecs-2021.8.2 | 6.0 MB    | 8          |   9%
# imagecodecs-2021.8.2 | 6.0 MB    | 9          |   9%
# imagecodecs-2021.8.2 | 6.0 MB    | 9          |  10%
# imagecodecs-2021.8.2 | 6.0 MB    | #          |  10%
# imagecodecs-2021.8.2 | 6.0 MB    | #          |  11%
# imagecodecs-2021.8.2 | 6.0 MB    | #1         |  11%
# imagecodecs-2021.8.2 | 6.0 MB    | #2         |  13%
# imagecodecs-2021.8.2 | 6.0 MB    | #3         |  14%
# imagecodecs-2021.8.2 | 6.0 MB    | #4         |  14%
# imagecodecs-2021.8.2 | 6.0 MB    | #5         |  15%
# imagecodecs-2021.8.2 | 6.0 MB    | #5         |  16%
# imagecodecs-2021.8.2 | 6.0 MB    | #6         |  16%
# imagecodecs-2021.8.2 | 6.0 MB    | #6         |  17%
# imagecodecs-2021.8.2 | 6.0 MB    | #7         |  18%
# imagecodecs-2021.8.2 | 6.0 MB    | #9         |  19%
# imagecodecs-2021.8.2 | 6.0 MB    | ##         |  20%
# imagecodecs-2021.8.2 | 6.0 MB    | ##         |  21%
# imagecodecs-2021.8.2 | 6.0 MB    | ##2        |  22%
# imagecodecs-2021.8.2 | 6.0 MB    | ##4        |  24%
# imagecodecs-2021.8.2 | 6.0 MB    | ##5        |  25%
# imagecodecs-2021.8.2 | 6.0 MB    | ##6        |  26%
# imagecodecs-2021.8.2 | 6.0 MB    | ##7        |  27%
# imagecodecs-2021.8.2 | 6.0 MB    | ##8        |  28%
# imagecodecs-2021.8.2 | 6.0 MB    | ##9        |  29%
# imagecodecs-2021.8.2 | 6.0 MB    | ###2       |  32%
# imagecodecs-2021.8.2 | 6.0 MB    | ###3       |  34%
# imagecodecs-2021.8.2 | 6.0 MB    | ###5       |  35%
# imagecodecs-2021.8.2 | 6.0 MB    | ###6       |  36%
# imagecodecs-2021.8.2 | 6.0 MB    | ###7       |  38%
# imagecodecs-2021.8.2 | 6.0 MB    | ###8       |  39%
# imagecodecs-2021.8.2 | 6.0 MB    | ####       |  40%
# imagecodecs-2021.8.2 | 6.0 MB    | ####1      |  41%
# imagecodecs-2021.8.2 | 6.0 MB    | ####2      |  42%
# imagecodecs-2021.8.2 | 6.0 MB    | ####6      |  47%
# imagecodecs-2021.8.2 | 6.0 MB    | ####8      |  48%
# imagecodecs-2021.8.2 | 6.0 MB    | #####      |  50%
# imagecodecs-2021.8.2 | 6.0 MB    | #####1     |  52%
# imagecodecs-2021.8.2 | 6.0 MB    | #####2     |  53%
# imagecodecs-2021.8.2 | 6.0 MB    | #####4     |  54%
# imagecodecs-2021.8.2 | 6.0 MB    | #####5     |  56%
# imagecodecs-2021.8.2 | 6.0 MB    | #####7     |  57%
# imagecodecs-2021.8.2 | 6.0 MB    | #####8     |  58%
# imagecodecs-2021.8.2 | 6.0 MB    | #####9     |  60%
# imagecodecs-2021.8.2 | 6.0 MB    | ######     |  61%
# imagecodecs-2021.8.2 | 6.0 MB    | ######2    |  63%
# imagecodecs-2021.8.2 | 6.0 MB    | ######6    |  66%
# imagecodecs-2021.8.2 | 6.0 MB    | ######8    |  68%
# imagecodecs-2021.8.2 | 6.0 MB    | ######9    |  70%
# imagecodecs-2021.8.2 | 6.0 MB    | #######3   |  73%
# imagecodecs-2021.8.2 | 6.0 MB    | #######5   |  76%
# imagecodecs-2021.8.2 | 6.0 MB    | #######7   |  78%

# %%
import hnswlib
import numpy as np

dim = 16
num_elements = 10000

# Generating sample data
data = np.float32(np.random.random((num_elements, dim)))

# We split the data in two batches:
data1 = data[:num_elements // 2]
data2 = data[num_elements // 2:]

# Declaring index
p = hnswlib.Index(space='l2', dim=dim)  # possible options are l2, cosine or ip

# Initializing index
# max_elements - the maximum number of elements (capacity). Will throw an exception if exceeded
# during insertion of an element.
# The capacity can be increased by saving/loading the index, see below.
#
# ef_construction - controls index search speed/build speed tradeoff
#
# M - is tightly connected with internal dimensionality of the data. Strongly affects memory consumption (~M)
# Higher M leads to higher accuracy/run_time at fixed ef/efConstruction

p.init_index(max_elements=num_elements//2, ef_construction=100, M=16)

# Controlling the recall by setting ef:
# higher ef leads to better accuracy, but slower search
p.set_ef(10)

# Set number of threads used during batch search/construction
# By default using all available cores
p.set_num_threads(4)


print("Adding first batch of %d elements" % (len(data1)))
p.add_items(data1)

# Query the elements for themselves and measure recall:
labels, distances = p.knn_query(data1, k=1)
print("Recall for the first batch:", np.mean(labels.reshape(-1) == np.arange(len(data1))), "\n")

# Serializing and deleting the index:
index_path='first_half.bin'
print("Saving index to '%s'" % index_path)
p.save_index("first_half.bin")
del p

# Re-initializing, loading the index
p = hnswlib.Index(space='l2', dim=dim)  # the space can be changed - keeps the data, alters the distance function.

print("\nLoading index from 'first_half.bin'\n")

# Increase the total capacity (max_elements), so that it will handle the new data
p.load_index("first_half.bin", max_elements = num_elements)

print("Adding the second batch of %d elements" % (len(data2)))
p.add_items(data2)

# Query the elements for themselves and measure recall:
labels, distances = p.knn_query(data, k=1)
print("Recall for two batches:", np.mean(labels.reshape(-1) == np.arange(len(data))), "\n")
# Out:
# Adding first batch of 5000 elements
# Recall for the first batch: 1.0
#
# Saving index to 'first_half.bin'
#
# Loading index from 'first_half.bin'
#
# Adding the second batch of 5000 elements
# Recall for two batches: 1.0

# %%
import numpy as np
d = 64                           # dimension
nb = 100000                      # database size
nq = 10000                       # nb of queries
np.random.seed(1234)             # make reproducible
xb = np.random.random((nb, d)).astype('float32')
xb[:, 0] += np.arange(nb) / 1000.
xq = np.random.random((nq, d)).astype('float32')
xq[:, 0] += np.arange(nq) / 1000.
# Out:
# imagecodecs-2021.8.2 | 6.0 MB    | #######9   |  79%
# imagecodecs-2021.8.2 | 6.0 MB    | ########1  |  81%
# imagecodecs-2021.8.2 | 6.0 MB    | ########2  |  83%
# imagecodecs-2021.8.2 | 6.0 MB    | ########5  |  85%
# imagecodecs-2021.8.2 | 6.0 MB    | ########6  |  87%
# imagecodecs-2021.8.2 | 6.0 MB    | ########8  |  88%
# imagecodecs-2021.8.2 | 6.0 MB    | #########  |  90%
# imagecodecs-2021.8.2 | 6.0 MB    | #########2 |  92%
# imagecodecs-2021.8.2 | 6.0 MB    | #########4 |  95%
# imagecodecs-2021.8.2 | 6.0 MB    | #########6 |  97%
# imagecodecs-2021.8.2 | 6.0 MB    | #########8 |  99%
# imagecodecs-2021.8.2 | 6.0 MB    | ########## | 100%
#
# conda-repo-cli-1.0.2 | 126 KB    |            |   0%
# conda-repo-cli-1.0.2 | 126 KB    | #2         |  13%
# conda-repo-cli-1.0.2 | 126 KB    | ##5        |  25%
# conda-repo-cli-1.0.2 | 126 KB    | ######3    |  63%
# conda-repo-cli-1.0.2 | 126 KB    | ########## | 100%
# conda-repo-cli-1.0.2 | 126 KB    | ########## | 100%
#
# pandas-1.4.4         | 8.7 MB    |            |   0%
# pandas-1.4.4         | 8.7 MB    |            |   0%
# pandas-1.4.4         | 8.7 MB    |            |   0%
# pandas-1.4.4         | 8.7 MB    |            |   1%
# pandas-1.4.4         | 8.7 MB    | 1          |   1%
# pandas-1.4.4         | 8.7 MB    | 1          |   2%
# pandas-1.4.4         | 8.7 MB    | 2          |   2%
# pandas-1.4.4         | 8.7 MB    | 2          |   3%
# pandas-1.4.4         | 8.7 MB    | 2          |   3%
# pandas-1.4.4         | 8.7 MB    | 3          |   3%
# pandas-1.4.4         | 8.7 MB    | 3          |   4%
# pandas-1.4.4         | 8.7 MB    | 4          |   4%
# pandas-1.4.4         | 8.7 MB    | 4          |   5%
# pandas-1.4.4         | 8.7 MB    | 5          |   5%
# pandas-1.4.4         | 8.7 MB    | 5          |   6%
# pandas-1.4.4         | 8.7 MB    | 5          |   6%
# pandas-1.4.4         | 8.7 MB    | 6          |   7%
# pandas-1.4.4         | 8.7 MB    | 7          |   7%
# pandas-1.4.4         | 8.7 MB    | 7          |   8%
# pandas-1.4.4         | 8.7 MB    | 8          |   8%
# pandas-1.4.4         | 8.7 MB    | 8          |   9%
# pandas-1.4.4         | 8.7 MB    | 9          |   9%
# pandas-1.4.4         | 8.7 MB    | 9          |  10%
# pandas-1.4.4         | 8.7 MB    | #          |  10%
# pandas-1.4.4         | 8.7 MB    | #          |  11%
# pandas-1.4.4         | 8.7 MB    | #1         |  12%
# pandas-1.4.4         | 8.7 MB    | #2         |  12%
# pandas-1.4.4         | 8.7 MB    | #2         |  12%
# pandas-1.4.4         | 8.7 MB    | #2         |  13%
# pandas-1.4.4         | 8.7 MB    | #3         |  13%
# pandas-1.4.4         | 8.7 MB    | #4         |  15%
# pandas-1.4.4         | 8.7 MB    | #5         |  16%
# pandas-1.4.4         | 8.7 MB    | #6         |  16%
# pandas-1.4.4         | 8.7 MB    | #6         |  17%
# pandas-1.4.4         | 8.7 MB    | #7         |  17%
# pandas-1.4.4         | 8.7 MB    | #8         |  19%
# pandas-1.4.4         | 8.7 MB    | #9         |  19%
# pandas-1.4.4         | 8.7 MB    | #9         |  20%
# pandas-1.4.4         | 8.7 MB    | ##         |  20%
# pandas-1.4.4         | 8.7 MB    | ##         |  20%
# pandas-1.4.4         | 8.7 MB    | ##         |  21%
# pandas-1.4.4         | 8.7 MB    | ##1        |  22%
# pandas-1.4.4         | 8.7 MB    | ##3        |  23%
# pandas-1.4.4         | 8.7 MB    | ##4        |  24%
# pandas-1.4.4         | 8.7 MB    | ##4        |  25%
# pandas-1.4.4         | 8.7 MB    | ##5        |  25%
# pandas-1.4.4         | 8.7 MB    | ##5        |  26%
# pandas-1.4.4         | 8.7 MB    | ##6        |  27%
# pandas-1.4.4         | 8.7 MB    | ##7        |  28%
# pandas-1.4.4         | 8.7 MB    | ##8        |  29%
# pandas-1.4.4         | 8.7 MB    | ##9        |  29%
# pandas-1.4.4         | 8.7 MB    | ###1       |  31%
# pandas-1.4.4         | 8.7 MB    | ###1       |  32%
# pandas-1.4.4         | 8.7 MB    | ###3       |  33%
# pandas-1.4.4         | 8.7 MB    | ###3       |  34%
# pandas-1.4.4         | 8.7 MB    | ###4       |  34%
# pandas-1.4.4         | 8.7 MB    | ###5       |  35%
# pandas-1.4.4         | 8.7 MB    | ###5       |  36%
# pandas-1.4.4         | 8.7 MB    | ###6       |  36%
# pandas-1.4.4         | 8.7 MB    | ###7       |  37%
# pandas-1.4.4         | 8.7 MB    | ###8       |  39%
# pandas-1.4.4         | 8.7 MB    | ###9       |  40%
# pandas-1.4.4         | 8.7 MB    | ####       |  40%
# pandas-1.4.4         | 8.7 MB    | ####3      |  44%
# pandas-1.4.4         | 8.7 MB    | ####4      |  44%
# pandas-1.4.4         | 8.7 MB    | ####5      |  45%
# pandas-1.4.4         | 8.7 MB    | ####7      |  48%
# pandas-1.4.4         | 8.7 MB    | ####8      |  49%
# pandas-1.4.4         | 8.7 MB    | #####      |  50%
# pandas-1.4.4         | 8.7 MB    | #####1     |  51%
# pandas-1.4.4         | 8.7 MB    | #####2     |  52%
# pandas-1.4.4         | 8.7 MB    | #####2     |  53%
# pandas-1.4.4         | 8.7 MB    | #####3     |  54%
# pandas-1.4.4         | 8.7 MB    | #####4     |  55%
# pandas-1.4.4         | 8.7 MB    | #####5     |  56%
# pandas-1.4.4         | 8.7 MB    | #####8     |  59%
# pandas-1.4.4         | 8.7 MB    | #####9     |  60%
# pandas-1.4.4         | 8.7 MB    | ######1    |  61%
# pandas-1.4.4         | 8.7 MB    | ######2    |  62%
# pandas-1.4.4         | 8.7 MB    | ######3    |  63%
# pandas-1.4.4         | 8.7 MB    | ######4    |  64%
# pandas-1.4.4         | 8.7 MB    | ######8    |  68%
# pandas-1.4.4         | 8.7 MB    | ######9    |  70%
# pandas-1.4.4         | 8.7 MB    | #######    |  71%
# pandas-1.4.4         | 8.7 MB    | #######2   |  72%
# pandas-1.4.4         | 8.7 MB    | #######3   |  73%
# pandas-1.4.4         | 8.7 MB    | #######5   |  76%
# pandas-1.4.4         | 8.7 MB    | #######7   |  78%
# pandas-1.4.4         | 8.7 MB    | #######9   |  79%
# pandas-1.4.4         | 8.7 MB    | ########   |  81%
# pandas-1.4.4         | 8.7 MB    | ########2  |  82%
# pandas-1.4.4         | 8.7 MB    | ########5  |  85%
# pandas-1.4.4         | 8.7 MB    | ########7  |  87%
# pandas-1.4.4         | 8.7 MB    | ########8  |  89%
# pandas-1.4.4         | 8.7 MB    | #########  |  90%
# pandas-1.4.4         | 8.7 MB    | #########5 |  96%
# pandas-1.4.4         | 8.7 MB    | #########7 |  98%
# pandas-1.4.4         | 8.7 MB    | #########9 | 100%
# pandas-1.4.4         | 8.7 MB    | ########## | 100%
#
# daal4py-2021.6.0     | 8.0 MB    |            |   0%
# daal4py-2021.6.0     | 8.0 MB    |            |   0%
# daal4py-2021.6.0     | 8.0 MB    |            |   0%
# daal4py-2021.6.0     | 8.0 MB    |            |   1%
# daal4py-2021.6.0     | 8.0 MB    | 1          |   2%
# daal4py-2021.6.0     | 8.0 MB    | 1          |   2%
# daal4py-2021.6.0     | 8.0 MB    | 2          |   2%
# daal4py-2021.6.0     | 8.0 MB    | 2          |   3%
# daal4py-2021.6.0     | 8.0 MB    | 3          |   4%
# daal4py-2021.6.0     | 8.0 MB    | 3          |   4%
# daal4py-2021.6.0     | 8.0 MB    | 4          |   4%
# daal4py-2021.6.0     | 8.0 MB    | 5          |   5%
# daal4py-2021.6.0     | 8.0 MB    | 5          |   6%
# daal4py-2021.6.0     | 8.0 MB    | 6          |   7%
# daal4py-2021.6.0     | 8.0 MB    | 7          |   7%
# daal4py-2021.6.0     | 8.0 MB    | 8          |   8%
# daal4py-2021.6.0     | 8.0 MB    | 8          |   8%
# daal4py-2021.6.0     | 8.0 MB    | 9          |   9%
# daal4py-2021.6.0     | 8.0 MB    | 9          |  10%
# daal4py-2021.6.0     | 8.0 MB    | #          |  11%
# daal4py-2021.6.0     | 8.0 MB    | #1         |  11%
# daal4py-2021.6.0     | 8.0 MB    | #1         |  12%
# daal4py-2021.6.0     | 8.0 MB    | #2         |  13%
# daal4py-2021.6.0     | 8.0 MB    | #2         |  13%
# daal4py-2021.6.0     | 8.0 MB    | #3         |  13%
# daal4py-2021.6.0     | 8.0 MB    | #4         |  14%
# daal4py-2021.6.0     | 8.0 MB    | #4         |  14%
# daal4py-2021.6.0     | 8.0 MB    | #4         |  15%
# daal4py-2021.6.0     | 8.0 MB    | #5         |  15%
# daal4py-2021.6.0     | 8.0 MB    | #6         |  16%
# daal4py-2021.6.0     | 8.0 MB    | #6         |  17%
# daal4py-2021.6.0     | 8.0 MB    | #7         |  17%
# daal4py-2021.6.0     | 8.0 MB    | #7         |  18%
# daal4py-2021.6.0     | 8.0 MB    | #8         |  18%
# daal4py-2021.6.0     | 8.0 MB    | #9         |  19%
# daal4py-2021.6.0     | 8.0 MB    | #9         |  20%
# daal4py-2021.6.0     | 8.0 MB    | ##         |  21%
# daal4py-2021.6.0     | 8.0 MB    | ##1        |  22%
# daal4py-2021.6.0     | 8.0 MB    | ##2        |  22%
# daal4py-2021.6.0     | 8.0 MB    | ##3        |  24%
# daal4py-2021.6.0     | 8.0 MB    | ##4        |  24%
# daal4py-2021.6.0     | 8.0 MB    | ##5        |  25%
# daal4py-2021.6.0     | 8.0 MB    | ##5        |  26%
# daal4py-2021.6.0     | 8.0 MB    | ##7        |  27%
# daal4py-2021.6.0     | 8.0 MB    | ##8        |  28%
# daal4py-2021.6.0     | 8.0 MB    | ##8        |  29%
# daal4py-2021.6.0     | 8.0 MB    | ##9        |  30%
# daal4py-2021.6.0     | 8.0 MB    | ###        |  30%
# daal4py-2021.6.0     | 8.0 MB    | ###1       |  31%
# daal4py-2021.6.0     | 8.0 MB    | ###1       |  32%
# daal4py-2021.6.0     | 8.0 MB    | ###3       |  33%
# daal4py-2021.6.0     | 8.0 MB    | ###4       |  34%
# daal4py-2021.6.0     | 8.0 MB    | ###4       |  35%
# daal4py-2021.6.0     | 8.0 MB    | ###6       |  36%
# daal4py-2021.6.0     | 8.0 MB    | ###7       |  38%
# daal4py-2021.6.0     | 8.0 MB    | ###8       |  39%
# daal4py-2021.6.0     | 8.0 MB    | ###9       |  40%
# daal4py-2021.6.0     | 8.0 MB    | ####1      |  41%
# daal4py-2021.6.0     | 8.0 MB    | ####2      |  43%
# daal4py-2021.6.0     | 8.0 MB    | ####3      |  44%
# daal4py-2021.6.0     | 8.0 MB    | ####5      |  45%
# daal4py-2021.6.0     | 8.0 MB    | ####7      |  47%
# daal4py-2021.6.0     | 8.0 MB    | ####8      |  49%
# daal4py-2021.6.0     | 8.0 MB    | #####      |  51%
# daal4py-2021.6.0     | 8.0 MB    | #####2     |  53%
# daal4py-2021.6.0     | 8.0 MB    | #####4     |  55%
# daal4py-2021.6.0     | 8.0 MB    | #####6     |  57%
# daal4py-2021.6.0     | 8.0 MB    | #####8     |  59%
# daal4py-2021.6.0     | 8.0 MB    | ######1    |  62%
# daal4py-2021.6.0     | 8.0 MB    | ######3    |  64%
# daal4py-2021.6.0     | 8.0 MB    | ######6    |  67%
# daal4py-2021.6.0     | 8.0 MB    | #######    |  70%
# daal4py-2021.6.0     | 8.0 MB    | #######3   |  73%
# daal4py-2021.6.0     | 8.0 MB    | #######6   |  77%
# daal4py-2021.6.0     | 8.0 MB    | ########   |  81%
# daal4py-2021.6.0     | 8.0 MB    | ########4  |  84%
# daal4py-2021.6.0     | 8.0 MB    | ########8  |  88%
# daal4py-2021.6.0     | 8.0 MB    | #########2 |  92%
# daal4py-2021.6.0     | 8.0 MB    | #########6 |  97%
# daal4py-2021.6.0     | 8.0 MB    | ########## | 100%
#
# libarchive-3.6.1     | 1.7 MB    |            |   0%
# libarchive-3.6.1     | 1.7 MB    |            |   1%
# libarchive-3.6.1     | 1.7 MB    | 2          |   3%
# libarchive-3.6.1     | 1.7 MB    | 3          |   4%
# libarchive-3.6.1     | 1.7 MB    | 6          |   6%
# libarchive-3.6.1     | 1.7 MB    | 8          |   8%
# libarchive-3.6.1     | 1.7 MB    | #          |  10%
# libarchive-3.6.1     | 1.7 MB    | #1         |  12%
# libarchive-3.6.1     | 1.7 MB    | #3         |  14%
# libarchive-3.6.1     | 1.7 MB    | #5         |  16%
# libarchive-3.6.1     | 1.7 MB    | #8         |  18%
# libarchive-3.6.1     | 1.7 MB    | ##1        |  21%
# libarchive-3.6.1     | 1.7 MB    | ##6        |  27%
# libarchive-3.6.1     | 1.7 MB    | ###2       |  32%
# libarchive-3.6.1     | 1.7 MB    | ###5       |  36%
# libarchive-3.6.1     | 1.7 MB    | ###8       |  39%
# libarchive-3.6.1     | 1.7 MB    | ####7      |  47%
# libarchive-3.6.1     | 1.7 MB    | ####9      |  50%
# libarchive-3.6.1     | 1.7 MB    | #####2     |  53%
# libarchive-3.6.1     | 1.7 MB    | #####7     |  57%
# libarchive-3.6.1     | 1.7 MB    | ######1    |  62%
# libarchive-3.6.1     | 1.7 MB    | #######1   |  71%
# libarchive-3.6.1     | 1.7 MB    | ########2  |  82%
# libarchive-3.6.1     | 1.7 MB    | ########7  |  88%
# libarchive-3.6.1     | 1.7 MB    | #########2 |  92%
# libarchive-3.6.1     | 1.7 MB    | ########## | 100%
# libarchive-3.6.1     | 1.7 MB    | ########## | 100%
#
# joblib-1.1.1         | 383 KB    |            |   0%
# joblib-1.1.1         | 383 KB    | 4          |   4%
# joblib-1.1.1         | 383 KB    | ########7  |  88%
# joblib-1.1.1         | 383 KB    | ########## | 100%
#
# soupsieve-2.3.2.post | 66 KB     |            |   0%
# soupsieve-2.3.2.post | 66 KB     | ########## | 100%
# soupsieve-2.3.2.post | 66 KB     | ########## | 100%
#
# xlwings-0.27.15      | 1.1 MB    |            |   0%
# xlwings-0.27.15      | 1.1 MB    | 1          |   1%
# xlwings-0.27.15      | 1.1 MB    | 4          |   4%
# xlwings-0.27.15      | 1.1 MB    | #          |  10%
# xlwings-0.27.15      | 1.1 MB    | #1         |  11%
# xlwings-0.27.15      | 1.1 MB    | #5         |  16%
# xlwings-0.27.15      | 1.1 MB    | #8         |  19%
# xlwings-0.27.15      | 1.1 MB    | ##         |  20%
# xlwings-0.27.15      | 1.1 MB    | ##2        |  23%
# xlwings-0.27.15      | 1.1 MB    | ##8        |  29%
# xlwings-0.27.15      | 1.1 MB    | ###3       |  33%
# xlwings-0.27.15      | 1.1 MB    | ###5       |  36%
# xlwings-0.27.15      | 1.1 MB    | ####       |  40%
# xlwings-0.27.15      | 1.1 MB    | ####4      |  45%
# xlwings-0.27.15      | 1.1 MB    | ####7      |  47%
# xlwings-0.27.15      | 1.1 MB    | #####      |  50%
# xlwings-0.27.15      | 1.1 MB    | #####4     |  55%
# xlwings-0.27.15      | 1.1 MB    | #####8     |  59%
# xlwings-0.27.15      | 1.1 MB    | ######1    |  62%
# xlwings-0.27.15      | 1.1 MB    | ######4    |  65%
# xlwings-0.27.15      | 1.1 MB    | #######    |  70%
# xlwings-0.27.15      | 1.1 MB    | #######3   |  73%
# xlwings-0.27.15      | 1.1 MB    | #######6   |  76%
# xlwings-0.27.15      | 1.1 MB    | ########   |  80%
# xlwings-0.27.15      | 1.1 MB    | ########4  |  85%
# xlwings-0.27.15      | 1.1 MB    | ########7  |  88%
# xlwings-0.27.15      | 1.1 MB    | #########  |  91%
# xlwings-0.27.15      | 1.1 MB    | ########## | 100%
# xlwings-0.27.15      | 1.1 MB    | ########## | 100%
#
# seaborn-0.12.0       | 435 KB    |            |   0%
# seaborn-0.12.0       | 435 KB    | 3          |   4%
# seaborn-0.12.0       | 435 KB    | ####4      |  44%
# seaborn-0.12.0       | 435 KB    | ######6    |  66%
# seaborn-0.12.0       | 435 KB    | ########   |  81%
# seaborn-0.12.0       | 435 KB    | ########## | 100%
# seaborn-0.12.0       | 435 KB    | ########## | 100%
#
# qtconsole-5.3.2      | 202 KB    |            |   0%
# qtconsole-5.3.2      | 202 KB    | ########## | 100%
# qtconsole-5.3.2      | 202 KB    | ########## | 100%
#
# libwebp-base-1.2.4   | 279 KB    |            |   0%
# libwebp-base-1.2.4   | 279 KB    | ########## | 100%
# libwebp-base-1.2.4   | 279 KB    | ########## | 100%
#
# zlib-1.2.13          | 113 KB    |            |   0%
# zlib-1.2.13          | 113 KB    | ########## | 100%
# zlib-1.2.13          | 113 KB    | ########## | 100%
#
# tzdata-2022e         | 107 KB    |            |   0%
# tzdata-2022e         | 107 KB    | ########## | 100%
# tzdata-2022e         | 107 KB    | ########## | 100%
#
# blosc-1.21.0         | 145 KB    |            |   0%
# blosc-1.21.0         | 145 KB    | #1         |  11%
# blosc-1.21.0         | 145 KB    | ########## | 100%
# blosc-1.21.0         | 145 KB    | ########## | 100%
#
# scipy-1.9.1          | 15.7 MB   |            |   0%
# scipy-1.9.1          | 15.7 MB   | 4          |   4%
# scipy-1.9.1          | 15.7 MB   | #          |  10%
# scipy-1.9.1          | 15.7 MB   | #5         |  16%
# scipy-1.9.1          | 15.7 MB   | ##         |  21%
# scipy-1.9.1          | 15.7 MB   | ##5        |  25%
# scipy-1.9.1          | 15.7 MB   | ##8        |  29%
# scipy-1.9.1          | 15.7 MB   | ###2       |  33%
# scipy-1.9.1          | 15.7 MB   | ###6       |  36%
# scipy-1.9.1          | 15.7 MB   | ###9       |  39%
# scipy-1.9.1          | 15.7 MB   | ####2      |  42%
# scipy-1.9.1          | 15.7 MB   | ####5      |  46%
# scipy-1.9.1          | 15.7 MB   | ####8      |  49%
# scipy-1.9.1          | 15.7 MB   | #####1     |  52%
# scipy-1.9.1          | 15.7 MB   | #####4     |  55%
# scipy-1.9.1          | 15.7 MB   | #####8     |  58%
# scipy-1.9.1          | 15.7 MB   | ######2    |  63%
# scipy-1.9.1          | 15.7 MB   | ######5    |  66%
# scipy-1.9.1          | 15.7 MB   | ######9    |  69%
# scipy-1.9.1          | 15.7 MB   | #######2   |  72%
# scipy-1.9.1          | 15.7 MB   | #######5   |  76%
# scipy-1.9.1          | 15.7 MB   | #######8   |  79%
# scipy-1.9.1          | 15.7 MB   | ########1  |  82%
# scipy-1.9.1          | 15.7 MB   | ########4  |  85%
# scipy-1.9.1          | 15.7 MB   | ########7  |  88%
# scipy-1.9.1          | 15.7 MB   | #########  |  91%
# scipy-1.9.1          | 15.7 MB   | #########4 |  94%
# scipy-1.9.1          | 15.7 MB   | #########6 |  97%
# scipy-1.9.1          | 15.7 MB   | ########## | 100%
# scipy-1.9.1          | 15.7 MB   | ########## | 100%
#
# async-timeout-4.0.2  | 12 KB     |            |   0%
# async-timeout-4.0.2  | 12 KB     | ########## | 100%
# async-timeout-4.0.2  | 12 KB     | ########## | 100%
#
# cryptography-38.0.1  | 991 KB    |            |   0%
# cryptography-38.0.1  | 991 KB    | #####9     |  60%
# cryptography-38.0.1  | 991 KB    | ########## | 100%
#
# anaconda-client-1.11 | 165 KB    |            |   0%
# anaconda-client-1.11 | 165 KB    | 9          |  10%
# anaconda-client-1.11 | 165 KB    | ##9        |  29%
# anaconda-client-1.11 | 165 KB    | ######7    |  68%
# anaconda-client-1.11 | 165 KB    | ########## | 100%
# anaconda-client-1.11 | 165 KB    | ########## | 100%
#
# zstd-1.5.2           | 509 KB    |            |   0%
# zstd-1.5.2           | 509 KB    | ########## | 100%
# zstd-1.5.2           | 509 KB    | ########## | 100%
#
# urllib3-1.26.12      | 185 KB    |            |   0%
# urllib3-1.26.12      | 185 KB    | ########## | 100%
# urllib3-1.26.12      | 185 KB    | ########## | 100%
#
# dal-2021.6.0         | 46.5 MB   |            |   0%
# dal-2021.6.0         | 46.5 MB   |            |   0%
# dal-2021.6.0         | 46.5 MB   |            |   0%
# dal-2021.6.0         | 46.5 MB   |            |   0%
# dal-2021.6.0         | 46.5 MB   |            |   0%
# dal-2021.6.0         | 46.5 MB   |            |   0%
# dal-2021.6.0         | 46.5 MB   |            |   0%
# dal-2021.6.0         | 46.5 MB   |            |   0%
# dal-2021.6.0         | 46.5 MB   |            |   1%
# dal-2021.6.0         | 46.5 MB   |            |   1%
# dal-2021.6.0         | 46.5 MB   |            |   1%
# dal-2021.6.0         | 46.5 MB   |            |   1%
# dal-2021.6.0         | 46.5 MB   |            |   1%
# dal-2021.6.0         | 46.5 MB   |            |   1%
# dal-2021.6.0         | 46.5 MB   |            |   1%
# dal-2021.6.0         | 46.5 MB   | 1          |   1%
# dal-2021.6.0         | 46.5 MB   | 1          |   1%
# dal-2021.6.0         | 46.5 MB   | 1          |   1%
# dal-2021.6.0         | 46.5 MB   | 1          |   1%
# dal-2021.6.0         | 46.5 MB   | 1          |   1%
# dal-2021.6.0         | 46.5 MB   | 1          |   2%
# dal-2021.6.0         | 46.5 MB   | 1          |   2%
# dal-2021.6.0         | 46.5 MB   | 2          |   2%
# dal-2021.6.0         | 46.5 MB   | 2          |   2%
# dal-2021.6.0         | 46.5 MB   | 2          |   2%
# dal-2021.6.0         | 46.5 MB   | 2          |   2%
# dal-2021.6.0         | 46.5 MB   | 2          |   3%
# dal-2021.6.0         | 46.5 MB   | 2          |   3%
# dal-2021.6.0         | 46.5 MB   | 3          |   3%
# dal-2021.6.0         | 46.5 MB   | 3          |   3%
# dal-2021.6.0         | 46.5 MB   | 3          |   3%
# dal-2021.6.0         | 46.5 MB   | 3          |   4%
# dal-2021.6.0         | 46.5 MB   | 3          |   4%
# dal-2021.6.0         | 46.5 MB   | 3          |   4%
# dal-2021.6.0         | 46.5 MB   | 3          |   4%
# dal-2021.6.0         | 46.5 MB   | 4          |   4%
# dal-2021.6.0         | 46.5 MB   | 4          |   4%
# dal-2021.6.0         | 46.5 MB   | 4          |   4%
# dal-2021.6.0         | 46.5 MB   | 4          |   5%
# dal-2021.6.0         | 46.5 MB   | 4          |   5%
# dal-2021.6.0         | 46.5 MB   | 4          |   5%
# dal-2021.6.0         | 46.5 MB   | 5          |   5%
# dal-2021.6.0         | 46.5 MB   | 5          |   5%
# dal-2021.6.0         | 46.5 MB   | 5          |   5%
# dal-2021.6.0         | 46.5 MB   | 5          |   6%
# dal-2021.6.0         | 46.5 MB   | 5          |   6%
# dal-2021.6.0         | 46.5 MB   | 5          |   6%
# dal-2021.6.0         | 46.5 MB   | 5          |   6%
# dal-2021.6.0         | 46.5 MB   | 6          |   7%
# dal-2021.6.0         | 46.5 MB   | 6          |   7%
# dal-2021.6.0         | 46.5 MB   | 6          |   7%
# dal-2021.6.0         | 46.5 MB   | 7          |   7%
# dal-2021.6.0         | 46.5 MB   | 7          |   7%
# dal-2021.6.0         | 46.5 MB   | 7          |   8%
# dal-2021.6.0         | 46.5 MB   | 7          |   8%
# dal-2021.6.0         | 46.5 MB   | 7          |   8%
# dal-2021.6.0         | 46.5 MB   | 8          |   8%
# dal-2021.6.0         | 46.5 MB   | 8          |   9%
# dal-2021.6.0         | 46.5 MB   | 8          |   9%
# dal-2021.6.0         | 46.5 MB   | 9          |   9%
# dal-2021.6.0         | 46.5 MB   | 9          |  10%
# dal-2021.6.0         | 46.5 MB   | 9          |  10%
# dal-2021.6.0         | 46.5 MB   | 9          |  10%
# dal-2021.6.0         | 46.5 MB   | #          |  10%
# dal-2021.6.0         | 46.5 MB   | #          |  10%
# dal-2021.6.0         | 46.5 MB   | #          |  11%
# dal-2021.6.0         | 46.5 MB   | #1         |  11%
# dal-2021.6.0         | 46.5 MB   | #1         |  11%
# dal-2021.6.0         | 46.5 MB   | #1         |  12%
# dal-2021.6.0         | 46.5 MB   | #1         |  12%
# dal-2021.6.0         | 46.5 MB   | #2         |  12%
# dal-2021.6.0         | 46.5 MB   | #3         |  13%
# dal-2021.6.0         | 46.5 MB   | #3         |  13%
# dal-2021.6.0         | 46.5 MB   | #4         |  14%
# dal-2021.6.0         | 46.5 MB   | #4         |  15%
# dal-2021.6.0         | 46.5 MB   | #5         |  15%
# dal-2021.6.0         | 46.5 MB   | #5         |  16%
# dal-2021.6.0         | 46.5 MB   | #6         |  16%
# dal-2021.6.0         | 46.5 MB   | #6         |  17%
# dal-2021.6.0         | 46.5 MB   | #7         |  17%
# dal-2021.6.0         | 46.5 MB   | #7         |  18%
# dal-2021.6.0         | 46.5 MB   | #9         |  19%
# dal-2021.6.0         | 46.5 MB   | #9         |  20%
# dal-2021.6.0         | 46.5 MB   | ##         |  20%
# dal-2021.6.0         | 46.5 MB   | ##         |  21%
# dal-2021.6.0         | 46.5 MB   | ##1        |  21%
# dal-2021.6.0         | 46.5 MB   | ##1        |  22%
# dal-2021.6.0         | 46.5 MB   | ##2        |  22%
# dal-2021.6.0         | 46.5 MB   | ##2        |  23%
# dal-2021.6.0         | 46.5 MB   | ##3        |  23%
# dal-2021.6.0         | 46.5 MB   | ##3        |  23%
# dal-2021.6.0         | 46.5 MB   | ##3        |  24%
# dal-2021.6.0         | 46.5 MB   | ##4        |  24%
# dal-2021.6.0         | 46.5 MB   | ##4        |  24%
# dal-2021.6.0         | 46.5 MB   | ##4        |  25%
# dal-2021.6.0         | 46.5 MB   | ##4        |  25%
# dal-2021.6.0         | 46.5 MB   | ##5        |  25%
# dal-2021.6.0         | 46.5 MB   | ##5        |  25%
# dal-2021.6.0         | 46.5 MB   | ##5        |  26%
# dal-2021.6.0         | 46.5 MB   | ##5        |  26%
# dal-2021.6.0         | 46.5 MB   | ##6        |  26%
# dal-2021.6.0         | 46.5 MB   | ##6        |  26%
# dal-2021.6.0         | 46.5 MB   | ##7        |  27%
# dal-2021.6.0         | 46.5 MB   | ##7        |  27%
# dal-2021.6.0         | 46.5 MB   | ##7        |  28%
# dal-2021.6.0         | 46.5 MB   | ##7        |  28%
# dal-2021.6.0         | 46.5 MB   | ##8        |  28%
# dal-2021.6.0         | 46.5 MB   | ##9        |  29%
# dal-2021.6.0         | 46.5 MB   | ##9        |  30%
# dal-2021.6.0         | 46.5 MB   | ##9        |  30%
# dal-2021.6.0         | 46.5 MB   | ###        |  30%
# dal-2021.6.0         | 46.5 MB   | ###        |  31%
# dal-2021.6.0         | 46.5 MB   | ###        |  31%
# dal-2021.6.0         | 46.5 MB   | ###1       |  31%
# dal-2021.6.0         | 46.5 MB   | ###1       |  32%
# dal-2021.6.0         | 46.5 MB   | ###2       |  32%
# dal-2021.6.0         | 46.5 MB   | ###2       |  32%
# dal-2021.6.0         | 46.5 MB   | ###2       |  33%
# dal-2021.6.0         | 46.5 MB   | ###2       |  33%
# dal-2021.6.0         | 46.5 MB   | ###3       |  33%
# dal-2021.6.0         | 46.5 MB   | ###3       |  34%
# dal-2021.6.0         | 46.5 MB   | ###3       |  34%
# dal-2021.6.0         | 46.5 MB   | ###4       |  34%
# dal-2021.6.0         | 46.5 MB   | ###4       |  34%
# dal-2021.6.0         | 46.5 MB   | ###5       |  35%
# dal-2021.6.0         | 46.5 MB   | ###5       |  36%
# dal-2021.6.0         | 46.5 MB   | ###6       |  37%
# dal-2021.6.0         | 46.5 MB   | ###7       |  37%
# dal-2021.6.0         | 46.5 MB   | ###7       |  38%
# dal-2021.6.0         | 46.5 MB   | ###8       |  38%
# dal-2021.6.0         | 46.5 MB   | ###8       |  39%
# dal-2021.6.0         | 46.5 MB   | ###9       |  39%
# dal-2021.6.0         | 46.5 MB   | ###9       |  39%
# dal-2021.6.0         | 46.5 MB   | ####       |  40%
# dal-2021.6.0         | 46.5 MB   | ####       |  41%
# dal-2021.6.0         | 46.5 MB   | ####1      |  42%
# dal-2021.6.0         | 46.5 MB   | ####2      |  42%
# dal-2021.6.0         | 46.5 MB   | ####2      |  43%
# dal-2021.6.0         | 46.5 MB   | ####3      |  43%
# dal-2021.6.0         | 46.5 MB   | ####3      |  44%
# dal-2021.6.0         | 46.5 MB   | ####4      |  44%
# dal-2021.6.0         | 46.5 MB   | ####4      |  45%
# dal-2021.6.0         | 46.5 MB   | ####5      |  46%
# dal-2021.6.0         | 46.5 MB   | ####7      |  48%
# dal-2021.6.0         | 46.5 MB   | ####8      |  49%
# dal-2021.6.0         | 46.5 MB   | ####9      |  50%
# dal-2021.6.0         | 46.5 MB   | #####      |  50%
# dal-2021.6.0         | 46.5 MB   | #####      |  51%
# dal-2021.6.0         | 46.5 MB   | #####2     |  52%
# dal-2021.6.0         | 46.5 MB   | #####3     |  53%
# dal-2021.6.0         | 46.5 MB   | #####4     |  54%
# dal-2021.6.0         | 46.5 MB   | #####5     |  55%
# dal-2021.6.0         | 46.5 MB   | #####7     |  57%
# dal-2021.6.0         | 46.5 MB   | #####9     |  59%
# dal-2021.6.0         | 46.5 MB   | ######     |  61%
# dal-2021.6.0         | 46.5 MB   | ######2    |  62%
# dal-2021.6.0         | 46.5 MB   | ######3    |  63%
# dal-2021.6.0         | 46.5 MB   | ######4    |  65%
# dal-2021.6.0         | 46.5 MB   | ######5    |  66%
# dal-2021.6.0         | 46.5 MB   | ######6    |  67%
# dal-2021.6.0         | 46.5 MB   | ######7    |  68%
# dal-2021.6.0         | 46.5 MB   | ######8    |  68%
# dal-2021.6.0         | 46.5 MB   | ######8    |  69%
# dal-2021.6.0         | 46.5 MB   | ######9    |  70%
# dal-2021.6.0         | 46.5 MB   | #######3   |  74%
# dal-2021.6.0         | 46.5 MB   | #######5   |  75%
# dal-2021.6.0         | 46.5 MB   | #######6   |  76%
# dal-2021.6.0         | 46.5 MB   | #######7   |  77%
# dal-2021.6.0         | 46.5 MB   | ########1  |  82%
# dal-2021.6.0         | 46.5 MB   | ########3  |  83%
# dal-2021.6.0         | 46.5 MB   | ########4  |  85%
# dal-2021.6.0         | 46.5 MB   | ########5  |  86%
# dal-2021.6.0         | 46.5 MB   | ########6  |  87%
# dal-2021.6.0         | 46.5 MB   | ########7  |  88%
# dal-2021.6.0         | 46.5 MB   | ########8  |  89%
# dal-2021.6.0         | 46.5 MB   | #########3 |  93%
# dal-2021.6.0         | 46.5 MB   | #########5 |  95%
# dal-2021.6.0         | 46.5 MB   | #########6 |  97%
# dal-2021.6.0         | 46.5 MB   | #########7 |  98%
# dal-2021.6.0         | 46.5 MB   | #########9 |  99%
# dal-2021.6.0         | 46.5 MB   | ########## | 100%
#
# jsonschema-4.16.0    | 143 KB    |            |   0%
# jsonschema-4.16.0    | 143 KB    | ########## | 100%
# jsonschema-4.16.0    | 143 KB    | ########## | 100%
#
# icc_rt-2022.1.0      | 6.5 MB    |            |   0%
# icc_rt-2022.1.0      | 6.5 MB    | 7          |   8%
# icc_rt-2022.1.0      | 6.5 MB    | ##2        |  22%
# icc_rt-2022.1.0      | 6.5 MB    | ###6       |  37%
# icc_rt-2022.1.0      | 6.5 MB    | ####9      |  50%
# icc_rt-2022.1.0      | 6.5 MB    | ######     |  61%
# icc_rt-2022.1.0      | 6.5 MB    | #######    |  70%
# icc_rt-2022.1.0      | 6.5 MB    | #######8   |  79%
# icc_rt-2022.1.0      | 6.5 MB    | ########7  |  87%
# icc_rt-2022.1.0      | 6.5 MB    | #########5 |  95%
# icc_rt-2022.1.0      | 6.5 MB    | ########## | 100%
#
# idna-3.4             | 93 KB     |            |   0%
# idna-3.4             | 93 KB     | ########## | 100%
# idna-3.4             | 93 KB     | ########## | 100%
#
# google-api-core-2.10 | 119 KB    |            |   0%
# google-api-core-2.10 | 119 KB    | #3         |  13%
# google-api-core-2.10 | 119 KB    | ####       |  40%
# google-api-core-2.10 | 119 KB    | ########## | 100%
# google-api-core-2.10 | 119 KB    | ########## | 100%
#
# tqdm-4.64.1          | 143 KB    |            |   0%
# tqdm-4.64.1          | 143 KB    | #1         |  11%
# tqdm-4.64.1          | 143 KB    | ####4      |  45%
# tqdm-4.64.1          | 143 KB    | ########## | 100%
# tqdm-4.64.1          | 143 KB    | ########## | 100%
#
# pip-22.2.2           | 2.3 MB    |            |   0%
# pip-22.2.2           | 2.3 MB    | ##         |  21%
# pip-22.2.2           | 2.3 MB    | #####8     |  59%
# pip-22.2.2           | 2.3 MB    | #########4 |  95%
# pip-22.2.2           | 2.3 MB    | ########## | 100%
#
# qtpy-2.2.0           | 106 KB    |            |   0%
# qtpy-2.2.0           | 106 KB    | ########## | 100%
# qtpy-2.2.0           | 106 KB    | ########## | 100%
#
# multidict-6.0.2      | 46 KB     |            |   0%
# multidict-6.0.2      | 46 KB     | ########## | 100%
# multidict-6.0.2      | 46 KB     | ########## | 100%
#
# cython-0.29.32       | 1.7 MB    |            |   0%
# cython-0.29.32       | 1.7 MB    |            |   1%
# cython-0.29.32       | 1.7 MB    | 2          |   3%
# cython-0.29.32       | 1.7 MB    | 6          |   6%
# cython-0.29.32       | 1.7 MB    | 7          |   7%
# cython-0.29.32       | 1.7 MB    | 9          |  10%
# cython-0.29.32       | 1.7 MB    | #3         |  14%
# cython-0.29.32       | 1.7 MB    | #5         |  15%
# cython-0.29.32       | 1.7 MB    | #7         |  17%
# cython-0.29.32       | 1.7 MB    | ##2        |  23%
# cython-0.29.32       | 1.7 MB    | ##4        |  24%
# cython-0.29.32       | 1.7 MB    | ##6        |  26%
# cython-0.29.32       | 1.7 MB    | ##8        |  28%
# cython-0.29.32       | 1.7 MB    | ##9        |  30%
# cython-0.29.32       | 1.7 MB    | ###1       |  32%
# cython-0.29.32       | 1.7 MB    | ###3       |  33%
# cython-0.29.32       | 1.7 MB    | ###5       |  35%
# cython-0.29.32       | 1.7 MB    | ###7       |  37%
# cython-0.29.32       | 1.7 MB    | ###8       |  39%
# cython-0.29.32       | 1.7 MB    | ####       |  41%
# cython-0.29.32       | 1.7 MB    | ####2      |  43%
# cython-0.29.32       | 1.7 MB    | ####4      |  44%
# cython-0.29.32       | 1.7 MB    | ####6      |  46%
# cython-0.29.32       | 1.7 MB    | ####7      |  48%
# cython-0.29.32       | 1.7 MB    | ####9      |  50%
# cython-0.29.32       | 1.7 MB    | #####2     |  52%
# cython-0.29.32       | 1.7 MB    | #####6     |  56%
# cython-0.29.32       | 1.7 MB    | #####9     |  60%
# cython-0.29.32       | 1.7 MB    | ######2    |  62%
# cython-0.29.32       | 1.7 MB    | #######1   |  71%
# cython-0.29.32       | 1.7 MB    | #######5   |  75%
# cython-0.29.32       | 1.7 MB    | #######8   |  79%
# cython-0.29.32       | 1.7 MB    | ########2  |  82%
# cython-0.29.32       | 1.7 MB    | ########5  |  86%
# cython-0.29.32       | 1.7 MB    | ########9  |  90%
# cython-0.29.32       | 1.7 MB    | #########3 |  93%
# cython-0.29.32       | 1.7 MB    | #########6 |  97%
# cython-0.29.32       | 1.7 MB    | #########9 |  99%
# cython-0.29.32       | 1.7 MB    | ########## | 100%
#
# libwebp-1.2.4        | 67 KB     |            |   0%
# libwebp-1.2.4        | 67 KB     | ########## | 100%
# libwebp-1.2.4        | 67 KB     | ########## | 100%
#
# tbb4py-2021.6.0      | 63 KB     |            |   0%
# tbb4py-2021.6.0      | 63 KB     | ##5        |  25%
# tbb4py-2021.6.0      | 63 KB     | ########## | 100%
# tbb4py-2021.6.0      | 63 KB     | ########## | 100%
#
# scikit-learn-intelex | 75 KB     |            |   0%
# scikit-learn-intelex | 75 KB     | ##1        |  21%
# scikit-learn-intelex | 75 KB     | ########## | 100%
# scikit-learn-intelex | 75 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Windows 64-bit packages of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
# done
# Retrieving notices: ...working... done

# %%
import faiss                   # make faiss available
index = faiss.IndexFlatL2(d)   # build the index
print(index.is_trained)
index.add(xb)                  # add vectors to the index
print(index.ntotal)
# Out:
# True
# 100000

# %%
k = 4                          # we want to see 4 nearest neighbors
D, I = index.search(xb[:5], k) # sanity check
print(I)
print(D)
D, I = index.search(xq, k)     # actual search
print(I[:5])                   # neighbors of the 5 first queries
print(I[-5:])                  # neighbors of the 5 last queries
# Out:
# [[  0 393 363  78]
#  [  1 555 277 364]
#  [  2 304 101  13]
#  [  3 173  18 182]
#  [  4 288 370 531]]
# [[0.        7.1751738 7.20763   7.2511625]
#  [0.        6.3235645 6.684581  6.799946 ]
#  [0.        5.7964087 6.391736  7.2815123]
#  [0.        7.2779055 7.527987  7.6628466]
#  [0.        6.7638035 7.2951202 7.3688145]]
# [[ 381  207  210  477]
#  [ 526  911  142   72]
#  [ 838  527 1290  425]
#  [ 196  184  164  359]
#  [ 526  377  120  425]]
# [[ 9900 10500  9309  9831]
#  [11055 10895 10812 11321]
#  [11353 11103 10164  9787]
#  [10571 10664 10632  9638]
#  [ 9628  9554 10036  9582]]
